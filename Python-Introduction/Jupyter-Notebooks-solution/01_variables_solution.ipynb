# %% [markdown]
# # 01 Variables and data types in Python
#
# ## Cells: code vs markdown
#
# - **Code cells**: contain Python code and are executed
# - **Markdown cells**: contain formatted text, explanations, notes
#
# ### Running your first cell

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## Comments
#
# Comments are notes for humans. Python ignores them.

# %%
# This is a comment
print("Python ignores the comment above")
# Out:
# Python ignores the comment above

# %% [markdown]
# ## Restart kernel & clear output
#
# Important notebook operations:
# - **Restart Kernel**: clears all variables from memory
# - **Clear Output**: removes displayed output but keeps code
#
# Execution order matters more than cell order.

# %% [markdown]
# # Variables
#
# ## Basic understanding
#
# Variables are **names for values**.
# - `=` assigns the value on the right to the name on the left
# - The variable is created when it is assigned

# %%
age = 42
first_name = 'Alice'

#TODO: change age to 45 and print the variable age and first_name
age = 45
print(age)
print(first_name)
# Out:
# Alice
# 45
# Alice

# %% [markdown]
# ## Variable names
#
# Variable names:
# - may contain letters, digits, and underscores
# - cannot start with a digit
# - are case-sensitive
# - should be meaningful
#
# ## Using print() with more arguments
#
# - `print()` is a built-in function
# - Arguments are passed inside parentheses
# - Spaces are added automatically

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Alice is 45 years old

# %% [markdown]
# ## Variables must exist before use

# %%
#TODO: define variable last_name
last_name = 'Smith'

print(last_name)

#TODO: print the whole sentence as in previous exercise and add last name

print(first_name, last_name, 'is', age, 'years old')
# Out:
# Smith
# Alice Smith is 45 years old

# %% [markdown]
# ## Variables in calculations
#
# - simple calculations +, -, *, /
#
# Variables only change when reassigned.

# %%
age = age + 3

print('Age in three years:', age)

#TODO: create new variable years and assign it value 10
years = 10

#TODO: substract years from age and print the result
age = age - years
print(age)
# Out:
# Age in three years: 48
# 38

# %%
a = 3
b = 2
#addition
c = a + b
#substraction
d = a - b
#multiplication
a = a * b
#division
f = a / b
#exponentiation
g = f ** b

print(g)
# Out:
# 9.0

# %% [markdown]
# # Data Types and Data Structures
#
# ## Fundamental types

# %%
integer_number = 10
floating_number = 3.14
text = 'hello'
flag = True

print(type(integer_number))
print(type(text))

#TODO: print the type of variable flag
print(type(flag))

#TODO: try to do sum of integer_number and floating number, what type is the result?
sum = integer_number + floating_number
print(sum)
print(type(sum))


number = '4'
#TODO: what data type is variable number? try to do multiplication of the variable number and integer number
print(type(number))
print(number * integer_number)

number = int(number)
print(number * integer_number)
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# 13.14
# <class 'float'>
# <class 'str'>
# 4444444444
# 40

# %% [markdown]
# ## Lists
#
# - Lists store multiple values.
# - Lists are **mutable**
# - Can store mixed types
# - Each value stored on one index (beginning from 0)
# - adding new element - .append()
# - removing element - .remove()

# %%
metadata = ['marc', 'frbr', 'mets', 'mods']

#printing whole list
print(metadata)

#printing first element
print(metadata[0])

metadata.append('cols')

#TODO: check whether the element 'cols' is in metadata
print(metadata)

#TODO: delete element 'frbf'
metadata.remove('frbr')
print(metadata)
# Out:
# ['marc', 'frbr', 'mets', 'mods']
# marc
# ['marc', 'frbr', 'mets', 'mods', 'cols']
# ['marc', 'mets', 'mods', 'cols']

# %% [markdown]
# ### Mixing data types

# %%
mixed = ['text', 3.5, [1, '2', 3]]

#TODO: create variable x and initialize it with 0
x = 0

#TODO: assing sum to x, the sum is consisting of second element of mixed list (3.5) and first element of third element of mixed list (1)

x = mixed[1] + mixed[2][0]
print(x)

#TODO: instead of 'text' assign x to first element of mixed list (element 'text' doesn't have to exist anymore)
mixed[0] = x
print(mixed)

#TODO: convert '2' to int but remain the rest of list same
mixed[2][1] = int(mixed[2][1])
print(mixed)
# Out:
# 4.5
# [4.5, 3.5, [1, '2', 3]]
# [4.5, 3.5, [1, 2, 3]]

# %% [markdown]
# ## Tuples
#
# A tuple is an ordered, immutable collection of items.
#
# Tuples are often used for:
# - fixed collections of values (e.g. coordinates)
# - returning multiple values from a function

# %%
coordinates = (50.087, 14.421)

print(coordinates[0])

# This will raise an error
coordinates[0] = 51.0
# Out:
# 50.087
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3911/2766591006.py in <cell line: 0>()
#       4
#       5 # This will raise an error
# ----> 6 coordinates[0] = 51.0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Mutable and immutable data types
# - list = mutable (we can do changes on already created list)
# - tuple = immutable (we cannot do changes on already created tuple)

# %%
# this works for tuple because we are creating a new one
t = (1, 2, 3)
t = t + (4,)

print(t)
# Out:
# (1, 2, 3, 4)

# %%
# assigning list a to variable b
a = [1, 2, 3]
b = a

print(b)

a.append(4)

print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
# assigning tuple a to variable b
a = (1, 2, 3)
b = a

print(b)

a = a + (4,)

print(b)
# Out:
# (1, 2, 3)
# (1, 2, 3)

# %% [markdown]
# ## Dictionaries
#
# A dictionary stores key–value pairs
# - access values using keys
# - add or update values
#
# Dictionaries are commonly used for:
# - structured data
# - records (rows in a table)
# - JSON-like data
#
# Based on the key we can easily look for the value

# %%
person = {
'name': 'Alice',
'age': 30,
'city': 'Prague'
}

print(person['name'])
print(person['age'])

#TODO: change the age to 31
person['age'] = 31

#adding new key and value:
person['email'] = 'alice@example.com'
print(person)

#TODO: add new key 'siblings' what type of values should we expect? choose data type and structure accordingly and assign the key some value
person['siblings'] = ['Bob', 'Eve']
print(person)
# Out:
# Alice
# 30
# {'name': 'Alice', 'age': 31, 'city': 'Prague', 'email': 'alice@example.com'}
# {'name': 'Alice', 'age': 31, 'city': 'Prague', 'email': 'alice@example.com', 'siblings': ['Bob', 'Eve']}

# %% [markdown]
# # Key takeaways
#
# - Variables store values
# - Python is case-sensitive
# - Every value has a type
# - Types control valid operations
# - Common data structures:
#     - list – ordered, mutable
#     - tuple – ordered, immutable
#     - dict – key–value pairs
